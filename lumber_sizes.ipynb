# %% [markdown]
# # Lumber Parts
# References:
# - Table of standard lumber sizes
#   http://mistupid.com/homeimpr/lumber.htm
# - TODO: https://www.engineeringtoolbox.com/green-kiln-dried-pressure-treated-lumber-weights-d_1860.html

# %%
# !conda install -y -n cq pandas requests beautifulsoup4

# %%
import pandas as pd
import requests
import bs4

# %%
lumber_sizes = "http://mistupid.com/homeimpr/lumber.htm"
resp = requests.get(lumber_sizes)
bs = bs4.BeautifulSoup(resp.text)

# %%
colnames = ['nominal', 'imperial', 'metric']

def extract_table(bs):
    tbl_html = bs.find_all('table')[2]
    # yield colnames
    for row in tbl_html.find_all('tr')[2:]:
        values = []
        for cell in row.find_all('td'):
            value = cell.text.replace(" ","").replace("\n","")
            values.append(value)
        yield values

rows = list(extract_table(bs))
rows
# Out:
# [['1"x2"', '3/4"x1-1/2"', '19x38mm'],
#  ['1"x3"', '3/4"x2-1/2"', '19x64mm'],
#  ['1"x4"', '3/4"x3-1/2"', '19x89mm'],
#  ['1"x5"', '3/4"x4-1/2"', '19x114mm'],
#  ['1"x6"', '3/4"x5-1/2"', '19x140mm'],
#  ['1"x7"', '3/4"x6-1/4"', '19x159mm'],
#  ['1"x8"', '3/4"x7-1/4"', '19x184mm'],
#  ['1"x10"', '3/4"x9-1/4"', '19x235mm'],
#  ['1"x12"', '3/4"x11-1/4"', '19x286mm'],
#  ['1-1/4"x4"', '1"x3-1/2"', '25x89mm'],
#  ['1-1/4"x6"', '1"x5-1/2"', '25x140mm'],
#  ['1-1/4"x8"', '1"x7-1/4"', '25x184mm'],
#  ['1-1/4"x10"', '1"x9-1/4"', '25x235mm'],
#  ['1-1/4"x12"', '1"x11-1/4"', '25x286mm'],
#  ['1-1/2"x4"', '1-1/4"x3-1/2"', '32x89mm'],
#  ['1-1/2"x6"', '1-1/4"x5-1/2"', '32x140mm'],
#  ['1-1/2"x8"', '1-1/4"x7-1/4"', '32x184mm'],
#  ['1-1/2"x10"', '1-1/4"x9-1/4"', '32x235mm'],
#  ['1-1/2"x12"', '1-1/4"x11-1/4"', '32x286mm'],
#  ['2"x2"', '1-1/2"x1-1/2"', '38x38mm'],
#  ['2"x4"', '1-1/2"x3-1/2"', '38x89mm'],
#  ['2"x6"', '1-1/2"x5-1/2"', '38x140mm'],
#  ['2"x8"', '1-1/2"x7-1/4"', '38x184mm'],
#  ['2"x10"', '1-1/2"x9-1/4"', '38x235mm'],
#  ['2"x12"', '1-1/2"x11-1/4"', '38x286mm'],
#  ['3"x6"', '2-1/2"x5-1/2"', '64x140mm'],
#  ['4"x4"', '3-1/2"x3-1/2"', '89x89mm'],
#  ['4"x6"', '3-1/2"x5-1/2"', '89x140mm']]

# %%
#from decimal import Decimal
from fractions import Fraction

def nominal2fraction(str_):
    _str = str_.rstrip('"')
    components = _str.split("-")
    value = Fraction(components.pop(0))
    if components:
        value += Fraction(components.pop())
    return value

def test_nominal2fraction():
    ios = [
        ["3/4\"", Fraction("3/4")],
        ["1-1/2", Fraction("3/2")],
        ["3-1/2", Fraction("7/2")],
    ]
    for io in ios:
        output = nominal2fraction(io[0])
        print(output, io[1])
        assert output == io[1]
    
test_nominal2fraction()
# Out:
# 3/4 3/4
# 3/2 3/2
# 7/2 7/2

# %%
def generate_object(row):
    nominal, imperial, metric = row
    obj = {
        "_row": row,
        "nominal": nominal,
        "imperial": imperial,
        "metric": metric
    }
    obj["nominal_h"], obj["nominal_w"] = nominal.split("x")
    obj["imperial_h"], obj["imperial_w"] = imperial.split("x")
    obj["metric_h"], obj["metric_w"] = metric.rstrip("m").split("x")
    
    obj["nominal_h_fraction"] = nominal2fraction(obj["nominal_h"])
    obj["nominal_w_fraction"] = nominal2fraction(obj["nominal_w"])
    obj["nominal_h_float"] = float(obj["nominal_h_fraction"])
    obj["nominal_w_float"] = float(obj["nominal_w_fraction"])
    
    
    obj["imperial_h_fraction"] = nominal2fraction(obj["imperial_h"])
    obj["imperial_w_fraction"] = nominal2fraction(obj["imperial_w"])
    obj["imperial_h_float"] = float(obj["imperial_h_fraction"])
    obj["imperial_w_float"] = float(obj["imperial_w_fraction"])
    
    obj["metric_h_float"] = float(obj["metric_h"])
    obj["metric_w_float"] = float(obj["metric_w"])
    
    obj['clsstr'] = nominal2clsstr(obj["nominal"])

    return obj

def nominal2clsstr(str_):
    return str_.replace('"','').replace("-","__").replace("/","_")

def test_nominal2clsstr():
    ios = [
        ["1x4", "1x4"],
        ['1-1/4\"x3-3/4"', "1__1_4x3__3_4"]
    ]
    for io in ios:
        assert nominal2clsstr(io[0]), io[1]

test_nominal2clsstr()
        
import json

class DecimalJSONEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, Fraction):
            return repr(obj)
        return json.JSONEncoder.default(self, obj)

import pprint
def test_generate_object(rows):
    for row in rows:
        obj = generate_object(row)
        #print(pprint.pformat(obj, indent=2))
        #print(obj)
        print(json.dumps(obj, cls=DecimalJSONEncoder, indent=1, sort_keys=True))
    #assert False
    
test_generate_object(rows)
# Out:
# {
#  "_row": [
#   "1\"x2\"",
#   "3/4\"x1-1/2\"",
#   "19x38mm"
#  ],
#  "clsstr": "1x2",
#  "imperial": "3/4\"x1-1/2\"",
#  "imperial_h": "3/4\"",
#  "imperial_h_float": 0.75,
#  "imperial_h_fraction": "Fraction(3, 4)",
#  "imperial_w": "1-1/2\"",
#  "imperial_w_float": 1.5,
#  "imperial_w_fraction": "Fraction(3, 2)",
#  "metric": "19x38mm",
#  "metric_h": "19",
#  "metric_h_float": 19.0,
#  "metric_w": "38",
#  "metric_w_float": 38.0,
#  "nominal": "1\"x2\"",
#  "nominal_h": "1\"",
#  "nominal_h_float": 1.0,
#  "nominal_h_fraction": "Fraction(1, 1)",
#  "nominal_w": "2\"",
#  "nominal_w_float": 2.0,
#  "nominal_w_fraction": "Fraction(2, 1)"
# }
# {
#  "_row": [
#   "1\"x3\"",
#   "3/4\"x2-1/2\"",
#   "19x64mm"
#  ],
#  "clsstr": "1x3",
#  "imperial": "3/4\"x2-1/2\"",
#  "imperial_h": "3/4\"",
#  "imperial_h_float": 0.75,
#  "imperial_h_fraction": "Fraction(3, 4)",
#  "imperial_w": "2-1/2\"",
#  "imperial_w_float": 2.5,
#  "imperial_w_fraction": "Fraction(5, 2)",
#  "metric": "19x64mm",
#  "metric_h": "19",
#  "metric_h_float": 19.0,
#  "metric_w": "64",
#  "metric_w_float": 64.0,
#  "nominal": "1\"x3\"",
#  "nominal_h": "1\"",
#  "nominal_h_float": 1.0,
#  "nominal_h_fraction": "Fraction(1, 1)",
#  "nominal_w": "3\"",
#  "nominal_w_float": 3.0,
#  "nominal_w_fraction": "Fraction(3, 1)"
# }
# {
#  "_row": [
#   "1\"x4\"",
#   "3/4\"x3-1/2\"",
#   "19x89mm"
#  ],
#  "clsstr": "1x4",
#  "imperial": "3/4\"x3-1/2\"",
#  "imperial_h": "3/4\"",
#  "imperial_h_float": 0.75,
#  "imperial_h_fraction": "Fraction(3, 4)",
#  "imperial_w": "3-1/2\"",
#  "imperial_w_float": 3.5,
#  "imperial_w_fraction": "Fraction(7, 2)",
#  "metric": "19x89mm",
#  "metric_h": "19",
#  "metric_h_float": 19.0,
#  "metric_w": "89",
#  "metric_w_float": 89.0,
#  "nominal": "1\"x4\"",
#  "nominal_h": "1\"",
#  "nominal_h_float": 1.0,
#  "nominal_h_fraction": "Fraction(1, 1)",
#  "nominal_w": "4\"",
#  "nominal_w_float": 4.0,
#  "nominal_w_fraction": "Fraction(4, 1)"
# }
# {
#  "_row": [
#   "1\"x5\"",
#   "3/4\"x4-1/2\"",
#   "19x114mm"
#  ],
#  "clsstr": "1x5",
#  "imperial": "3/4\"x4-1/2\"",
#  "imperial_h": "3/4\"",
#  "imperial_h_float": 0.75,
#  "imperial_h_fraction": "Fraction(3, 4)",
#  "imperial_w": "4-1/2\"",
#  "imperial_w_float": 4.5,
#  "imperial_w_fraction": "Fraction(9, 2)",
#  "metric": "19x114mm",
#  "metric_h": "19",
#  "metric_h_float": 19.0,
#  "metric_w": "114",
#  "metric_w_float": 114.0,
#  "nominal": "1\"x5\"",
#  "nominal_h": "1\"",
#  "nominal_h_float": 1.0,
#  "nominal_h_fraction": "Fraction(1, 1)",
#  "nominal_w": "5\"",
#  "nominal_w_float": 5.0,
#  "nominal_w_fraction": "Fraction(5, 1)"
# }
# {
#  "_row": [
#   "1\"x6\"",
#   "3/4\"x5-1/2\"",
#   "19x140mm"
#  ],
#  "clsstr": "1x6",
#  "imperial": "3/4\"x5-1/2\"",
#  "imperial_h": "3/4\"",
#  "imperial_h_float": 0.75,
#  "imperial_h_fraction": "Fraction(3, 4)",
#  "imperial_w": "5-1/2\"",
#  "imperial_w_float": 5.5,
#  "imperial_w_fraction": "Fraction(11, 2)",
#  "metric": "19x140mm",
#  "metric_h": "19",
#  "metric_h_float": 19.0,
#  "metric_w": "140",
#  "metric_w_float": 140.0,
#  "nominal": "1\"x6\"",
#  "nominal_h": "1\"",
#  "nominal_h_float": 1.0,
#  "nominal_h_fraction": "Fraction(1, 1)",
#  "nominal_w": "6\"",
#  "nominal_w_float": 6.0,
#  "nominal_w_fraction": "Fraction(6, 1)"
# }
# {
#  "_row": [
#   "1\"x7\"",
#   "3/4\"x6-1/4\"",
#   "19x159mm"
#  ],
#  "clsstr": "1x7",
#  "imperial": "3/4\"x6-1/4\"",
#  "imperial_h": "3/4\"",
#  "imperial_h_float": 0.75,
#  "imperial_h_fraction": "Fraction(3, 4)",
#  "imperial_w": "6-1/4\"",
#  "imperial_w_float": 6.25,
#  "imperial_w_fraction": "Fraction(25, 4)",
#  "metric": "19x159mm",
#  "metric_h": "19",
#  "metric_h_float": 19.0,
#  "metric_w": "159",
#  "metric_w_float": 159.0,
#  "nominal": "1\"x7\"",
#  "nominal_h": "1\"",
#  "nominal_h_float": 1.0,
#  "nominal_h_fraction": "Fraction(1, 1)",
#  "nominal_w": "7\"",
#  "nominal_w_float": 7.0,
#  "nominal_w_fraction": "Fraction(7, 1)"
# }
# {
#  "_row": [
#   "1\"x8\"",
#   "3/4\"x7-1/4\"",
#   "19x184mm"
#  ],
#  "clsstr": "1x8",
#  "imperial": "3/4\"x7-1/4\"",
#  "imperial_h": "3/4\"",
#  "imperial_h_float": 0.75,
#  "imperial_h_fraction": "Fraction(3, 4)",
#  "imperial_w": "7-1/4\"",
#  "imperial_w_float": 7.25,
#  "imperial_w_fraction": "Fraction(29, 4)",
#  "metric": "19x184mm",
#  "metric_h": "19",
#  "metric_h_float": 19.0,
#  "metric_w": "184",
#  "metric_w_float": 184.0,
#  "nominal": "1\"x8\"",
#  "nominal_h": "1\"",
#  "nominal_h_float": 1.0,
#  "nominal_h_fraction": "Fraction(1, 1)",
#  "nominal_w": "8\"",
#  "nominal_w_float": 8.0,
#  "nominal_w_fraction": "Fraction(8, 1)"
# }
# {
#  "_row": [
#   "1\"x10\"",
#   "3/4\"x9-1/4\"",
#   "19x235mm"
#  ],
#  "clsstr": "1x10",
#  "imperial": "3/4\"x9-1/4\"",
#  "imperial_h": "3/4\"",
#  "imperial_h_float": 0.75,
#  "imperial_h_fraction": "Fraction(3, 4)",
#  "imperial_w": "9-1/4\"",
#  "imperial_w_float": 9.25,
#  "imperial_w_fraction": "Fraction(37, 4)",
#  "metric": "19x235mm",
#  "metric_h": "19",
#  "metric_h_float": 19.0,
#  "metric_w": "235",
#  "metric_w_float": 235.0,
#  "nominal": "1\"x10\"",
#  "nominal_h": "1\"",
#  "nominal_h_float": 1.0,
#  "nominal_h_fraction": "Fraction(1, 1)",
#  "nominal_w": "10\"",
#  "nominal_w_float": 10.0,
#  "nominal_w_fraction": "Fraction(10, 1)"
# }
# {
#  "_row": [
#   "1\"x12\"",
#   "3/4\"x11-1/4\"",
#   "19x286mm"
#  ],
#  "clsstr": "1x12",
#  "imperial": "3/4\"x11-1/4\"",
#  "imperial_h": "3/4\"",
#  "imperial_h_float": 0.75,
#  "imperial_h_fraction": "Fraction(3, 4)",
#  "imperial_w": "11-1/4\"",
#  "imperial_w_float": 11.25,
#  "imperial_w_fraction": "Fraction(45, 4)",
#  "metric": "19x286mm",
#  "metric_h": "19",
#  "metric_h_float": 19.0,
#  "metric_w": "286",
#  "metric_w_float": 286.0,
#  "nominal": "1\"x12\"",
#  "nominal_h": "1\"",
#  "nominal_h_float": 1.0,
#  "nominal_h_fraction": "Fraction(1, 1)",
#  "nominal_w": "12\"",
#  "nominal_w_float": 12.0,
#  "nominal_w_fraction": "Fraction(12, 1)"
# }
# {
#  "_row": [
#   "1-1/4\"x4\"",
#   "1\"x3-1/2\"",
#   "25x89mm"
#  ],
#  "clsstr": "1__1_4x4",
#  "imperial": "1\"x3-1/2\"",
#  "imperial_h": "1\"",
#  "imperial_h_float": 1.0,
#  "imperial_h_fraction": "Fraction(1, 1)",
#  "imperial_w": "3-1/2\"",
#  "imperial_w_float": 3.5,
#  "imperial_w_fraction": "Fraction(7, 2)",
#  "metric": "25x89mm",
#  "metric_h": "25",
#  "metric_h_float": 25.0,
#  "metric_w": "89",
#  "metric_w_float": 89.0,
#  "nominal": "1-1/4\"x4\"",
#  "nominal_h": "1-1/4\"",
#  "nominal_h_float": 1.25,
#  "nominal_h_fraction": "Fraction(5, 4)",
#  "nominal_w": "4\"",
#  "nominal_w_float": 4.0,
#  "nominal_w_fraction": "Fraction(4, 1)"
# }
# {
#  "_row": [
#   "1-1/4\"x6\"",
#   "1\"x5-1/2\"",
#   "25x140mm"
#  ],
#  "clsstr": "1__1_4x6",
#  "imperial": "1\"x5-1/2\"",
#  "imperial_h": "1\"",
#  "imperial_h_float": 1.0,
#  "imperial_h_fraction": "Fraction(1, 1)",
#  "imperial_w": "5-1/2\"",
#  "imperial_w_float": 5.5,
#  "imperial_w_fraction": "Fraction(11, 2)",
#  "metric": "25x140mm",
#  "metric_h": "25",
#  "metric_h_float": 25.0,
#  "metric_w": "140",
#  "metric_w_float": 140.0,
#  "nominal": "1-1/4\"x6\"",
#  "nominal_h": "1-1/4\"",
#  "nominal_h_float": 1.25,
#  "nominal_h_fraction": "Fraction(5, 4)",
#  "nominal_w": "6\"",
#  "nominal_w_float": 6.0,
#  "nominal_w_fraction": "Fraction(6, 1)"
# }
# {
#  "_row": [
#   "1-1/4\"x8\"",
#   "1\"x7-1/4\"",
#   "25x184mm"
#  ],
#  "clsstr": "1__1_4x8",
#  "imperial": "1\"x7-1/4\"",
#  "imperial_h": "1\"",
#  "imperial_h_float": 1.0,
#  "imperial_h_fraction": "Fraction(1, 1)",
#  "imperial_w": "7-1/4\"",
#  "imperial_w_float": 7.25,
#  "imperial_w_fraction": "Fraction(29, 4)",
#  "metric": "25x184mm",
#  "metric_h": "25",
#  "metric_h_float": 25.0,
#  "metric_w": "184",
#  "metric_w_float": 184.0,
#  "nominal": "1-1/4\"x8\"",
#  "nominal_h": "1-1/4\"",
#  "nominal_h_float": 1.25,
#  "nominal_h_fraction": "Fraction(5, 4)",
#  "nominal_w": "8\"",
#  "nominal_w_float": 8.0,
#  "nominal_w_fraction": "Fraction(8, 1)"
# }
# {
#  "_row": [
#   "1-1/4\"x10\"",
#   "1\"x9-1/4\"",
#   "25x235mm"
#  ],
#  "clsstr": "1__1_4x10",
#  "imperial": "1\"x9-1/4\"",
#  "imperial_h": "1\"",
#  "imperial_h_float": 1.0,
#  "imperial_h_fraction": "Fraction(1, 1)",
#  "imperial_w": "9-1/4\"",
#  "imperial_w_float": 9.25,
#  "imperial_w_fraction": "Fraction(37, 4)",
#  "metric": "25x235mm",
#  "metric_h": "25",
#  "metric_h_float": 25.0,
#  "metric_w": "235",
#  "metric_w_float": 235.0,
#  "nominal": "1-1/4\"x10\"",
#  "nominal_h": "1-1/4\"",
#  "nominal_h_float": 1.25,
#  "nominal_h_fraction": "Fraction(5, 4)",
#  "nominal_w": "10\"",
#  "nominal_w_float": 10.0,
#  "nominal_w_fraction": "Fraction(10, 1)"
# }
# {
#  "_row": [
#   "1-1/4\"x12\"",
#   "1\"x11-1/4\"",
#   "25x286mm"
#  ],
#  "clsstr": "1__1_4x12",
#  "imperial": "1\"x11-1/4\"",
#  "imperial_h": "1\"",
#  "imperial_h_float": 1.0,
#  "imperial_h_fraction": "Fraction(1, 1)",
#  "imperial_w": "11-1/4\"",
#  "imperial_w_float": 11.25,
#  "imperial_w_fraction": "Fraction(45, 4)",
#  "metric": "25x286mm",
#  "metric_h": "25",
#  "metric_h_float": 25.0,
#  "metric_w": "286",
#  "metric_w_float": 286.0,
#  "nominal": "1-1/4\"x12\"",
#  "nominal_h": "1-1/4\"",
#  "nominal_h_float": 1.25,
#  "nominal_h_fraction": "Fraction(5, 4)",
#  "nominal_w": "12\"",
#  "nominal_w_float": 12.0,
#  "nominal_w_fraction": "Fraction(12, 1)"
# }
# {
#  "_row": [
#   "1-1/2\"x4\"",
#   "1-1/4\"x3-1/2\"",
#   "32x89mm"
#  ],
#  "clsstr": "1__1_2x4",
#  "imperial": "1-1/4\"x3-1/2\"",
#  "imperial_h": "1-1/4\"",
#  "imperial_h_float": 1.25,
#  "imperial_h_fraction": "Fraction(5, 4)",
#  "imperial_w": "3-1/2\"",
#  "imperial_w_float": 3.5,
#  "imperial_w_fraction": "Fraction(7, 2)",
#  "metric": "32x89mm",
#  "metric_h": "32",
#  "metric_h_float": 32.0,
#  "metric_w": "89",
#  "metric_w_float": 89.0,
#  "nominal": "1-1/2\"x4\"",
#  "nominal_h": "1-1/2\"",
#  "nominal_h_float": 1.5,
#  "nominal_h_fraction": "Fraction(3, 2)",
#  "nominal_w": "4\"",
#  "nominal_w_float": 4.0,
#  "nominal_w_fraction": "Fraction(4, 1)"
# }
# {
#  "_row": [
#   "1-1/2\"x6\"",
#   "1-1/4\"x5-1/2\"",
#   "32x140mm"
#  ],
#  "clsstr": "1__1_2x6",
#  "imperial": "1-1/4\"x5-1/2\"",
#  "imperial_h": "1-1/4\"",
#  "imperial_h_float": 1.25,
#  "imperial_h_fraction": "Fraction(5, 4)",
#  "imperial_w": "5-1/2\"",
#  "imperial_w_float": 5.5,
#  "imperial_w_fraction": "Fraction(11, 2)",
#  "metric": "32x140mm",
#  "metric_h": "32",
#  "metric_h_float": 32.0,
#  "metric_w": "140",
#  "metric_w_float": 140.0,
#  "nominal": "1-1/2\"x6\"",
#  "nominal_h": "1-1/2\"",
#  "nominal_h_float": 1.5,
#  "nominal_h_fraction": "Fraction(3, 2)",
#  "nominal_w": "6\"",
#  "nominal_w_float": 6.0,
#  "nominal_w_fraction": "Fraction(6, 1)"
# }
# {
#  "_row": [
#   "1-1/2\"x8\"",
#   "1-1/4\"x7-1/4\"",
#   "32x184mm"
#  ],
#  "clsstr": "1__1_2x8",
#  "imperial": "1-1/4\"x7-1/4\"",
#  "imperial_h": "1-1/4\"",
#  "imperial_h_float": 1.25,
#  "imperial_h_fraction": "Fraction(5, 4)",
#  "imperial_w": "7-1/4\"",
#  "imperial_w_float": 7.25,
#  "imperial_w_fraction": "Fraction(29, 4)",
#  "metric": "32x184mm",
#  "metric_h": "32",
#  "metric_h_float": 32.0,
#  "metric_w": "184",
#  "metric_w_float": 184.0,
#  "nominal": "1-1/2\"x8\"",
#  "nominal_h": "1-1/2\"",
#  "nominal_h_float": 1.5,
#  "nominal_h_fraction": "Fraction(3, 2)",
#  "nominal_w": "8\"",
#  "nominal_w_float": 8.0,
#  "nominal_w_fraction": "Fraction(8, 1)"
# }
# {
#  "_row": [
#   "1-1/2\"x10\"",
#   "1-1/4\"x9-1/4\"",
#   "32x235mm"
#  ],
#  "clsstr": "1__1_2x10",
#  "imperial": "1-1/4\"x9-1/4\"",
#  "imperial_h": "1-1/4\"",
#  "imperial_h_float": 1.25,
#  "imperial_h_fraction": "Fraction(5, 4)",
#  "imperial_w": "9-1/4\"",
#  "imperial_w_float": 9.25,
#  "imperial_w_fraction": "Fraction(37, 4)",
#  "metric": "32x235mm",
#  "metric_h": "32",
#  "metric_h_float": 32.0,
#  "metric_w": "235",
#  "metric_w_float": 235.0,
#  "nominal": "1-1/2\"x10\"",
#  "nominal_h": "1-1/2\"",
#  "nominal_h_float": 1.5,
#  "nominal_h_fraction": "Fraction(3, 2)",
#  "nominal_w": "10\"",
#  "nominal_w_float": 10.0,
#  "nominal_w_fraction": "Fraction(10, 1)"
# }
# {
#  "_row": [
#   "1-1/2\"x12\"",
#   "1-1/4\"x11-1/4\"",
#   "32x286mm"
#  ],
#  "clsstr": "1__1_2x12",
#  "imperial": "1-1/4\"x11-1/4\"",
#  "imperial_h": "1-1/4\"",
#  "imperial_h_float": 1.25,
#  "imperial_h_fraction": "Fraction(5, 4)",
#  "imperial_w": "11-1/4\"",
#  "imperial_w_float": 11.25,
#  "imperial_w_fraction": "Fraction(45, 4)",
#  "metric": "32x286mm",
#  "metric_h": "32",
#  "metric_h_float": 32.0,
#  "metric_w": "286",
#  "metric_w_float": 286.0,
#  "nominal": "1-1/2\"x12\"",
#  "nominal_h": "1-1/2\"",
#  "nominal_h_float": 1.5,
#  "nominal_h_fraction": "Fraction(3, 2)",
#  "nominal_w": "12\"",
#  "nominal_w_float": 12.0,
#  "nominal_w_fraction": "Fraction(12, 1)"
# }
# {
#  "_row": [
#   "2\"x2\"",
#   "1-1/2\"x1-1/2\"",
#   "38x38mm"
#  ],
#  "clsstr": "2x2",
#  "imperial": "1-1/2\"x1-1/2\"",
#  "imperial_h": "1-1/2\"",
#  "imperial_h_float": 1.5,
#  "imperial_h_fraction": "Fraction(3, 2)",
#  "imperial_w": "1-1/2\"",
#  "imperial_w_float": 1.5,
#  "imperial_w_fraction": "Fraction(3, 2)",
#  "metric": "38x38mm",
#  "metric_h": "38",
#  "metric_h_float": 38.0,
#  "metric_w": "38",
#  "metric_w_float": 38.0,
#  "nominal": "2\"x2\"",
#  "nominal_h": "2\"",
#  "nominal_h_float": 2.0,
#  "nominal_h_fraction": "Fraction(2, 1)",
#  "nominal_w": "2\"",
#  "nominal_w_float": 2.0,
#  "nominal_w_fraction": "Fraction(2, 1)"
# }
# {
#  "_row": [
#   "2\"x4\"",
#   "1-1/2\"x3-1/2\"",
#   "38x89mm"
#  ],
#  "clsstr": "2x4",
#  "imperial": "1-1/2\"x3-1/2\"",
#  "imperial_h": "1-1/2\"",
#  "imperial_h_float": 1.5,
#  "imperial_h_fraction": "Fraction(3, 2)",
#  "imperial_w": "3-1/2\"",
#  "imperial_w_float": 3.5,
#  "imperial_w_fraction": "Fraction(7, 2)",
#  "metric": "38x89mm",
#  "metric_h": "38",
#  "metric_h_float": 38.0,
#  "metric_w": "89",
#  "metric_w_float": 89.0,
#  "nominal": "2\"x4\"",
#  "nominal_h": "2\"",
#  "nominal_h_float": 2.0,
#  "nominal_h_fraction": "Fraction(2, 1)",
#  "nominal_w": "4\"",
#  "nominal_w_float": 4.0,
#  "nominal_w_fraction": "Fraction(4, 1)"
# }
# {
#  "_row": [
#   "2\"x6\"",
#   "1-1/2\"x5-1/2\"",
#   "38x140mm"
#  ],
#  "clsstr": "2x6",
#  "imperial": "1-1/2\"x5-1/2\"",
#  "imperial_h": "1-1/2\"",
#  "imperial_h_float": 1.5,
#  "imperial_h_fraction": "Fraction(3, 2)",
#  "imperial_w": "5-1/2\"",
#  "imperial_w_float": 5.5,
#  "imperial_w_fraction": "Fraction(11, 2)",
#  "metric": "38x140mm",
#  "metric_h": "38",
#  "metric_h_float": 38.0,
#  "metric_w": "140",
#  "metric_w_float": 140.0,
#  "nominal": "2\"x6\"",
#  "nominal_h": "2\"",
#  "nominal_h_float": 2.0,
#  "nominal_h_fraction": "Fraction(2, 1)",
#  "nominal_w": "6\"",
#  "nominal_w_float": 6.0,
#  "nominal_w_fraction": "Fraction(6, 1)"
# }
# {
#  "_row": [
#   "2\"x8\"",
#   "1-1/2\"x7-1/4\"",
#   "38x184mm"
#  ],
#  "clsstr": "2x8",
#  "imperial": "1-1/2\"x7-1/4\"",
#  "imperial_h": "1-1/2\"",
#  "imperial_h_float": 1.5,
#  "imperial_h_fraction": "Fraction(3, 2)",
#  "imperial_w": "7-1/4\"",
#  "imperial_w_float": 7.25,
#  "imperial_w_fraction": "Fraction(29, 4)",
#  "metric": "38x184mm",
#  "metric_h": "38",
#  "metric_h_float": 38.0,
#  "metric_w": "184",
#  "metric_w_float": 184.0,
#  "nominal": "2\"x8\"",
#  "nominal_h": "2\"",
#  "nominal_h_float": 2.0,
#  "nominal_h_fraction": "Fraction(2, 1)",
#  "nominal_w": "8\"",
#  "nominal_w_float": 8.0,
#  "nominal_w_fraction": "Fraction(8, 1)"
# }
# {
#  "_row": [
#   "2\"x10\"",
#   "1-1/2\"x9-1/4\"",
#   "38x235mm"
#  ],
#  "clsstr": "2x10",
#  "imperial": "1-1/2\"x9-1/4\"",
#  "imperial_h": "1-1/2\"",
#  "imperial_h_float": 1.5,
#  "imperial_h_fraction": "Fraction(3, 2)",
#  "imperial_w": "9-1/4\"",
#  "imperial_w_float": 9.25,
#  "imperial_w_fraction": "Fraction(37, 4)",
#  "metric": "38x235mm",
#  "metric_h": "38",
#  "metric_h_float": 38.0,
#  "metric_w": "235",
#  "metric_w_float": 235.0,
#  "nominal": "2\"x10\"",
#  "nominal_h": "2\"",
#  "nominal_h_float": 2.0,
#  "nominal_h_fraction": "Fraction(2, 1)",
#  "nominal_w": "10\"",
#  "nominal_w_float": 10.0,
#  "nominal_w_fraction": "Fraction(10, 1)"
# }
# {
#  "_row": [
#   "2\"x12\"",
#   "1-1/2\"x11-1/4\"",
#   "38x286mm"
#  ],
#  "clsstr": "2x12",
#  "imperial": "1-1/2\"x11-1/4\"",
#  "imperial_h": "1-1/2\"",
#  "imperial_h_float": 1.5,
#  "imperial_h_fraction": "Fraction(3, 2)",
#  "imperial_w": "11-1/4\"",
#  "imperial_w_float": 11.25,
#  "imperial_w_fraction": "Fraction(45, 4)",
#  "metric": "38x286mm",
#  "metric_h": "38",
#  "metric_h_float": 38.0,
#  "metric_w": "286",
#  "metric_w_float": 286.0,
#  "nominal": "2\"x12\"",
#  "nominal_h": "2\"",
#  "nominal_h_float": 2.0,
#  "nominal_h_fraction": "Fraction(2, 1)",
#  "nominal_w": "12\"",
#  "nominal_w_float": 12.0,
#  "nominal_w_fraction": "Fraction(12, 1)"
# }
# {
#  "_row": [
#   "3\"x6\"",
#   "2-1/2\"x5-1/2\"",
#   "64x140mm"
#  ],
#  "clsstr": "3x6",
#  "imperial": "2-1/2\"x5-1/2\"",
#  "imperial_h": "2-1/2\"",
#  "imperial_h_float": 2.5,
#  "imperial_h_fraction": "Fraction(5, 2)",
#  "imperial_w": "5-1/2\"",
#  "imperial_w_float": 5.5,
#  "imperial_w_fraction": "Fraction(11, 2)",
#  "metric": "64x140mm",
#  "metric_h": "64",
#  "metric_h_float": 64.0,
#  "metric_w": "140",
#  "metric_w_float": 140.0,
#  "nominal": "3\"x6\"",
#  "nominal_h": "3\"",
#  "nominal_h_float": 3.0,
#  "nominal_h_fraction": "Fraction(3, 1)",
#  "nominal_w": "6\"",
#  "nominal_w_float": 6.0,
#  "nominal_w_fraction": "Fraction(6, 1)"
# }
# {
#  "_row": [
#   "4\"x4\"",
#   "3-1/2\"x3-1/2\"",
#   "89x89mm"
#  ],
#  "clsstr": "4x4",
#  "imperial": "3-1/2\"x3-1/2\"",
#  "imperial_h": "3-1/2\"",
#  "imperial_h_float": 3.5,
#  "imperial_h_fraction": "Fraction(7, 2)",
#  "imperial_w": "3-1/2\"",
#  "imperial_w_float": 3.5,
#  "imperial_w_fraction": "Fraction(7, 2)",
#  "metric": "89x89mm",
#  "metric_h": "89",
#  "metric_h_float": 89.0,
#  "metric_w": "89",
#  "metric_w_float": 89.0,
#  "nominal": "4\"x4\"",
#  "nominal_h": "4\"",
#  "nominal_h_float": 4.0,
#  "nominal_h_fraction": "Fraction(4, 1)",
#  "nominal_w": "4\"",
#  "nominal_w_float": 4.0,
#  "nominal_w_fraction": "Fraction(4, 1)"
# }
# {
#  "_row": [
#   "4\"x6\"",
#   "3-1/2\"x5-1/2\"",
#   "89x140mm"
#  ],
#  "clsstr": "4x6",
#  "imperial": "3-1/2\"x5-1/2\"",
#  "imperial_h": "3-1/2\"",
#  "imperial_h_float": 3.5,
#  "imperial_h_fraction": "Fraction(7, 2)",
#  "imperial_w": "5-1/2\"",
#  "imperial_w_float": 5.5,
#  "imperial_w_fraction": "Fraction(11, 2)",
#  "metric": "89x140mm",
#  "metric_h": "89",
#  "metric_h_float": 89.0,
#  "metric_w": "140",
#  "metric_w_float": 140.0,
#  "nominal": "4\"x6\"",
#  "nominal_h": "4\"",
#  "nominal_h_float": 4.0,
#  "nominal_h_fraction": "Fraction(4, 1)",
#  "nominal_w": "6\"",
#  "nominal_w_float": 6.0,
#  "nominal_w_fraction": "Fraction(6, 1)"
# }

# %%
UNIT_TEXT = {
    "metric": "metric (mm)",
    "imperial": "imperial (in)"
}

def generate_class(obj, unit='imperial'):
    if unit not in ["metric", "imperial"]:
        raise ValueError("unit must be either 'metric' or 'imperial'")
    class_template = '''
@register("{dict_entry}")
class Lumber{clsstr}(Lumber):
    """a {nominal} ({actual_size}) piece of Lumber"""
    height = PositiveFloat({height}, doc="height of lumber in {unit_text} units (default: {height})")
    width = PositiveFloat({width}, doc="thickness of lumber in {unit_text} units (default: {width})")
'''
    
    context = {}
    context['unit_text'] = UNIT_TEXT.get(unit)
    context['height'] = obj["%s_h_float" % unit]
    context['width'] = obj["%s_w_float" % unit]
    context['actual_size'] = obj[unit]
    context['dict_entry'] = obj["nominal"].replace('"','')
    return class_template.format(**context, **obj)
    
  
DEFAULT_LENGTH = {
    "metric": 304.8,  # ~= 12.0in
    "imperial": 12.0
}
    
def generate_classes(objects, unit='imperial', template='wood_dark'):
    length = DEFAULT_LENGTH.get(unit)
    if length is None:
        raise ValueError("units must be either 'metric' (mm) or 'imperial'")
    unit_text = UNIT_TEXT.get(unit)
    lumbercls = '''
"""
Lumber classes for {unit_text} units
"""
import cqparts
from cqparts.params import PositiveFloat
from cqparts.display import render_props

class Lumber(cqparts.Part):
    length = PositiveFloat({length}, doc="length of lumber in {unit_text} units (default: {length})")
    _render = render_props(template='{template}')

    def make(self):
        return (
            cq.Workplane("XY")
            .box(self.length, self.height, self.width))


CLASSES = {{}}

def register(cls, *keys):
    for key in keys:
        CLASSES[key] = cls
    return cls
'''
    output = []
    output.append(lumbercls.format(length=length, unit_text=unit_text, template=template))
    for obj in objects:
        output.append(generate_class(obj, unit=unit))
    return '\n'.join(output)

def test_generate_classes():
    objs = [generate_object(row) for row in rows]
    for unit in ["imperial", "metric"]:
        print("\n####  %s\n" % unit)
        output = generate_classes(objs, unit=unit)
        print(output)

test_generate_classes()
# Out:
# ####  imperial
#
#
# """
# Lumber classes for imperial (in) units
# """
# import cqparts
# from cqparts.params import PositiveFloat
# from cqparts.display import render_props
#
# class Lumber(cqparts.Part):
#     length = PositiveFloat(12.0, doc="length of lumber in imperial (in) units (default: 12.0)")
#     _render = render_props(template='wood_dark')
#
#     def make(self):
#         return (
#             cq.Workplane("XY")
#             .box(self.length, self.height, self.width))
#
#
# CLASSES = {}
#
# def register(cls, *keys):
#     for key in keys:
#         CLASSES[key] = cls
#     return cls
#
#
# @register("1x2")
# class Lumber1x2(Lumber):
#     """a 1"x2" (3/4"x1-1/2") piece of Lumber"""
#     height = PositiveFloat(0.75, doc="height of lumber in imperial (in) units (default: 0.75)")
#     width = PositiveFloat(1.5, doc="thickness of lumber in imperial (in) units (default: 1.5)")
#
#
# @register("1x3")
# class Lumber1x3(Lumber):
#     """a 1"x3" (3/4"x2-1/2") piece of Lumber"""
#     height = PositiveFloat(0.75, doc="height of lumber in imperial (in) units (default: 0.75)")
#     width = PositiveFloat(2.5, doc="thickness of lumber in imperial (in) units (default: 2.5)")
#
#
# @register("1x4")
# class Lumber1x4(Lumber):
#     """a 1"x4" (3/4"x3-1/2") piece of Lumber"""
#     height = PositiveFloat(0.75, doc="height of lumber in imperial (in) units (default: 0.75)")
#     width = PositiveFloat(3.5, doc="thickness of lumber in imperial (in) units (default: 3.5)")
#
#
# @register("1x5")
# class Lumber1x5(Lumber):
#     """a 1"x5" (3/4"x4-1/2") piece of Lumber"""
#     height = PositiveFloat(0.75, doc="height of lumber in imperial (in) units (default: 0.75)")
#     width = PositiveFloat(4.5, doc="thickness of lumber in imperial (in) units (default: 4.5)")
#
#
# @register("1x6")
# class Lumber1x6(Lumber):
#     """a 1"x6" (3/4"x5-1/2") piece of Lumber"""
#     height = PositiveFloat(0.75, doc="height of lumber in imperial (in) units (default: 0.75)")
#     width = PositiveFloat(5.5, doc="thickness of lumber in imperial (in) units (default: 5.5)")
#
#
# @register("1x7")
# class Lumber1x7(Lumber):
#     """a 1"x7" (3/4"x6-1/4") piece of Lumber"""
#     height = PositiveFloat(0.75, doc="height of lumber in imperial (in) units (default: 0.75)")
#     width = PositiveFloat(6.25, doc="thickness of lumber in imperial (in) units (default: 6.25)")
#
#
# @register("1x8")
# class Lumber1x8(Lumber):
#     """a 1"x8" (3/4"x7-1/4") piece of Lumber"""
#     height = PositiveFloat(0.75, doc="height of lumber in imperial (in) units (default: 0.75)")
#     width = PositiveFloat(7.25, doc="thickness of lumber in imperial (in) units (default: 7.25)")
#
#
# @register("1x10")
# class Lumber1x10(Lumber):
#     """a 1"x10" (3/4"x9-1/4") piece of Lumber"""
#     height = PositiveFloat(0.75, doc="height of lumber in imperial (in) units (default: 0.75)")
#     width = PositiveFloat(9.25, doc="thickness of lumber in imperial (in) units (default: 9.25)")
#
#
# @register("1x12")
# class Lumber1x12(Lumber):
#     """a 1"x12" (3/4"x11-1/4") piece of Lumber"""
#     height = PositiveFloat(0.75, doc="height of lumber in imperial (in) units (default: 0.75)")
#     width = PositiveFloat(11.25, doc="thickness of lumber in imperial (in) units (default: 11.25)")
#
#
# @register("1-1/4x4")
# class Lumber1__1_4x4(Lumber):
#     """a 1-1/4"x4" (1"x3-1/2") piece of Lumber"""
#     height = PositiveFloat(1.0, doc="height of lumber in imperial (in) units (default: 1.0)")
#     width = PositiveFloat(3.5, doc="thickness of lumber in imperial (in) units (default: 3.5)")
#
#
# @register("1-1/4x6")
# class Lumber1__1_4x6(Lumber):
#     """a 1-1/4"x6" (1"x5-1/2") piece of Lumber"""
#     height = PositiveFloat(1.0, doc="height of lumber in imperial (in) units (default: 1.0)")
#     width = PositiveFloat(5.5, doc="thickness of lumber in imperial (in) units (default: 5.5)")
#
#
# @register("1-1/4x8")
# class Lumber1__1_4x8(Lumber):
#     """a 1-1/4"x8" (1"x7-1/4") piece of Lumber"""
#     height = PositiveFloat(1.0, doc="height of lumber in imperial (in) units (default: 1.0)")
#     width = PositiveFloat(7.25, doc="thickness of lumber in imperial (in) units (default: 7.25)")
#
#
# @register("1-1/4x10")
# class Lumber1__1_4x10(Lumber):
#     """a 1-1/4"x10" (1"x9-1/4") piece of Lumber"""
#     height = PositiveFloat(1.0, doc="height of lumber in imperial (in) units (default: 1.0)")
#     width = PositiveFloat(9.25, doc="thickness of lumber in imperial (in) units (default: 9.25)")
#
#
# @register("1-1/4x12")
# class Lumber1__1_4x12(Lumber):
#     """a 1-1/4"x12" (1"x11-1/4") piece of Lumber"""
#     height = PositiveFloat(1.0, doc="height of lumber in imperial (in) units (default: 1.0)")
#     width = PositiveFloat(11.25, doc="thickness of lumber in imperial (in) units (default: 11.25)")
#
#
# @register("1-1/2x4")
# class Lumber1__1_2x4(Lumber):
#     """a 1-1/2"x4" (1-1/4"x3-1/2") piece of Lumber"""
#     height = PositiveFloat(1.25, doc="height of lumber in imperial (in) units (default: 1.25)")
#     width = PositiveFloat(3.5, doc="thickness of lumber in imperial (in) units (default: 3.5)")
#
#
# @register("1-1/2x6")
# class Lumber1__1_2x6(Lumber):
#     """a 1-1/2"x6" (1-1/4"x5-1/2") piece of Lumber"""
#     height = PositiveFloat(1.25, doc="height of lumber in imperial (in) units (default: 1.25)")
#     width = PositiveFloat(5.5, doc="thickness of lumber in imperial (in) units (default: 5.5)")
#
#
# @register("1-1/2x8")
# class Lumber1__1_2x8(Lumber):
#     """a 1-1/2"x8" (1-1/4"x7-1/4") piece of Lumber"""
#     height = PositiveFloat(1.25, doc="height of lumber in imperial (in) units (default: 1.25)")
#     width = PositiveFloat(7.25, doc="thickness of lumber in imperial (in) units (default: 7.25)")
#
#
# @register("1-1/2x10")
# class Lumber1__1_2x10(Lumber):
#     """a 1-1/2"x10" (1-1/4"x9-1/4") piece of Lumber"""
#     height = PositiveFloat(1.25, doc="height of lumber in imperial (in) units (default: 1.25)")
#     width = PositiveFloat(9.25, doc="thickness of lumber in imperial (in) units (default: 9.25)")
#
#
# @register("1-1/2x12")
# class Lumber1__1_2x12(Lumber):
#     """a 1-1/2"x12" (1-1/4"x11-1/4") piece of Lumber"""
#     height = PositiveFloat(1.25, doc="height of lumber in imperial (in) units (default: 1.25)")
#     width = PositiveFloat(11.25, doc="thickness of lumber in imperial (in) units (default: 11.25)")
#
#
# @register("2x2")
# class Lumber2x2(Lumber):
#     """a 2"x2" (1-1/2"x1-1/2") piece of Lumber"""
#     height = PositiveFloat(1.5, doc="height of lumber in imperial (in) units (default: 1.5)")
#     width = PositiveFloat(1.5, doc="thickness of lumber in imperial (in) units (default: 1.5)")
#
#
# @register("2x4")
# class Lumber2x4(Lumber):
#     """a 2"x4" (1-1/2"x3-1/2") piece of Lumber"""
#     height = PositiveFloat(1.5, doc="height of lumber in imperial (in) units (default: 1.5)")
#     width = PositiveFloat(3.5, doc="thickness of lumber in imperial (in) units (default: 3.5)")
#
#
# @register("2x6")
# class Lumber2x6(Lumber):
#     """a 2"x6" (1-1/2"x5-1/2") piece of Lumber"""
#     height = PositiveFloat(1.5, doc="height of lumber in imperial (in) units (default: 1.5)")
#     width = PositiveFloat(5.5, doc="thickness of lumber in imperial (in) units (default: 5.5)")
#
#
# @register("2x8")
# class Lumber2x8(Lumber):
#     """a 2"x8" (1-1/2"x7-1/4") piece of Lumber"""
#     height = PositiveFloat(1.5, doc="height of lumber in imperial (in) units (default: 1.5)")
#     width = PositiveFloat(7.25, doc="thickness of lumber in imperial (in) units (default: 7.25)")
#
#
# @register("2x10")
# class Lumber2x10(Lumber):
#     """a 2"x10" (1-1/2"x9-1/4") piece of Lumber"""
#     height = PositiveFloat(1.5, doc="height of lumber in imperial (in) units (default: 1.5)")
#     width = PositiveFloat(9.25, doc="thickness of lumber in imperial (in) units (default: 9.25)")
#
#
# @register("2x12")
# class Lumber2x12(Lumber):
#     """a 2"x12" (1-1/2"x11-1/4") piece of Lumber"""
#     height = PositiveFloat(1.5, doc="height of lumber in imperial (in) units (default: 1.5)")
#     width = PositiveFloat(11.25, doc="thickness of lumber in imperial (in) units (default: 11.25)")
#
#
# @register("3x6")
# class Lumber3x6(Lumber):
#     """a 3"x6" (2-1/2"x5-1/2") piece of Lumber"""
#     height = PositiveFloat(2.5, doc="height of lumber in imperial (in) units (default: 2.5)")
#     width = PositiveFloat(5.5, doc="thickness of lumber in imperial (in) units (default: 5.5)")
#
#
# @register("4x4")
# class Lumber4x4(Lumber):
#     """a 4"x4" (3-1/2"x3-1/2") piece of Lumber"""
#     height = PositiveFloat(3.5, doc="height of lumber in imperial (in) units (default: 3.5)")
#     width = PositiveFloat(3.5, doc="thickness of lumber in imperial (in) units (default: 3.5)")
#
#
# @register("4x6")
# class Lumber4x6(Lumber):
#     """a 4"x6" (3-1/2"x5-1/2") piece of Lumber"""
#     height = PositiveFloat(3.5, doc="height of lumber in imperial (in) units (default: 3.5)")
#     width = PositiveFloat(5.5, doc="thickness of lumber in imperial (in) units (default: 5.5)")
#
#
# ####  metric
#
#
# """
# Lumber classes for metric (mm) units
# """
# import cqparts
# from cqparts.params import PositiveFloat
# from cqparts.display import render_props
#
# class Lumber(cqparts.Part):
#     length = PositiveFloat(304.8, doc="length of lumber in metric (mm) units (default: 304.8)")
#     _render = render_props(template='wood_dark')
#
#     def make(self):
#         return (
#             cq.Workplane("XY")
#             .box(self.length, self.height, self.width))
#
#
# CLASSES = {}
#
# def register(cls, *keys):
#     for key in keys:
#         CLASSES[key] = cls
#     return cls
#
#
# @register("1x2")
# class Lumber1x2(Lumber):
#     """a 1"x2" (19x38mm) piece of Lumber"""
#     height = PositiveFloat(19.0, doc="height of lumber in metric (mm) units (default: 19.0)")
#     width = PositiveFloat(38.0, doc="thickness of lumber in metric (mm) units (default: 38.0)")
#
#
# @register("1x3")
# class Lumber1x3(Lumber):
#     """a 1"x3" (19x64mm) piece of Lumber"""
#     height = PositiveFloat(19.0, doc="height of lumber in metric (mm) units (default: 19.0)")
#     width = PositiveFloat(64.0, doc="thickness of lumber in metric (mm) units (default: 64.0)")
#
#
# @register("1x4")
# class Lumber1x4(Lumber):
#     """a 1"x4" (19x89mm) piece of Lumber"""
#     height = PositiveFloat(19.0, doc="height of lumber in metric (mm) units (default: 19.0)")
#     width = PositiveFloat(89.0, doc="thickness of lumber in metric (mm) units (default: 89.0)")
#
#
# @register("1x5")
# class Lumber1x5(Lumber):
#     """a 1"x5" (19x114mm) piece of Lumber"""
#     height = PositiveFloat(19.0, doc="height of lumber in metric (mm) units (default: 19.0)")
#     width = PositiveFloat(114.0, doc="thickness of lumber in metric (mm) units (default: 114.0)")
#
#
# @register("1x6")
# class Lumber1x6(Lumber):
#     """a 1"x6" (19x140mm) piece of Lumber"""
#     height = PositiveFloat(19.0, doc="height of lumber in metric (mm) units (default: 19.0)")
#     width = PositiveFloat(140.0, doc="thickness of lumber in metric (mm) units (default: 140.0)")
#
#
# @register("1x7")
# class Lumber1x7(Lumber):
#     """a 1"x7" (19x159mm) piece of Lumber"""
#     height = PositiveFloat(19.0, doc="height of lumber in metric (mm) units (default: 19.0)")
#     width = PositiveFloat(159.0, doc="thickness of lumber in metric (mm) units (default: 159.0)")
#
#
# @register("1x8")
# class Lumber1x8(Lumber):
#     """a 1"x8" (19x184mm) piece of Lumber"""
#     height = PositiveFloat(19.0, doc="height of lumber in metric (mm) units (default: 19.0)")
#     width = PositiveFloat(184.0, doc="thickness of lumber in metric (mm) units (default: 184.0)")
#
#
# @register("1x10")
# class Lumber1x10(Lumber):
#     """a 1"x10" (19x235mm) piece of Lumber"""
#     height = PositiveFloat(19.0, doc="height of lumber in metric (mm) units (default: 19.0)")
#     width = PositiveFloat(235.0, doc="thickness of lumber in metric (mm) units (default: 235.0)")
#
#
# @register("1x12")
# class Lumber1x12(Lumber):
#     """a 1"x12" (19x286mm) piece of Lumber"""
#     height = PositiveFloat(19.0, doc="height of lumber in metric (mm) units (default: 19.0)")
#     width = PositiveFloat(286.0, doc="thickness of lumber in metric (mm) units (default: 286.0)")
#
#
# @register("1-1/4x4")
# class Lumber1__1_4x4(Lumber):
#     """a 1-1/4"x4" (25x89mm) piece of Lumber"""
#     height = PositiveFloat(25.0, doc="height of lumber in metric (mm) units (default: 25.0)")
#     width = PositiveFloat(89.0, doc="thickness of lumber in metric (mm) units (default: 89.0)")
#
#
# @register("1-1/4x6")
# class Lumber1__1_4x6(Lumber):
#     """a 1-1/4"x6" (25x140mm) piece of Lumber"""
#     height = PositiveFloat(25.0, doc="height of lumber in metric (mm) units (default: 25.0)")
#     width = PositiveFloat(140.0, doc="thickness of lumber in metric (mm) units (default: 140.0)")
#
#
# @register("1-1/4x8")
# class Lumber1__1_4x8(Lumber):
#     """a 1-1/4"x8" (25x184mm) piece of Lumber"""
#     height = PositiveFloat(25.0, doc="height of lumber in metric (mm) units (default: 25.0)")
#     width = PositiveFloat(184.0, doc="thickness of lumber in metric (mm) units (default: 184.0)")
#
#
# @register("1-1/4x10")
# class Lumber1__1_4x10(Lumber):
#     """a 1-1/4"x10" (25x235mm) piece of Lumber"""
#     height = PositiveFloat(25.0, doc="height of lumber in metric (mm) units (default: 25.0)")
#     width = PositiveFloat(235.0, doc="thickness of lumber in metric (mm) units (default: 235.0)")
#
#
# @register("1-1/4x12")
# class Lumber1__1_4x12(Lumber):
#     """a 1-1/4"x12" (25x286mm) piece of Lumber"""
#     height = PositiveFloat(25.0, doc="height of lumber in metric (mm) units (default: 25.0)")
#     width = PositiveFloat(286.0, doc="thickness of lumber in metric (mm) units (default: 286.0)")
#
#
# @register("1-1/2x4")
# class Lumber1__1_2x4(Lumber):
#     """a 1-1/2"x4" (32x89mm) piece of Lumber"""
#     height = PositiveFloat(32.0, doc="height of lumber in metric (mm) units (default: 32.0)")
#     width = PositiveFloat(89.0, doc="thickness of lumber in metric (mm) units (default: 89.0)")
#
#
# @register("1-1/2x6")
# class Lumber1__1_2x6(Lumber):
#     """a 1-1/2"x6" (32x140mm) piece of Lumber"""
#     height = PositiveFloat(32.0, doc="height of lumber in metric (mm) units (default: 32.0)")
#     width = PositiveFloat(140.0, doc="thickness of lumber in metric (mm) units (default: 140.0)")
#
#
# @register("1-1/2x8")
# class Lumber1__1_2x8(Lumber):
#     """a 1-1/2"x8" (32x184mm) piece of Lumber"""
#     height = PositiveFloat(32.0, doc="height of lumber in metric (mm) units (default: 32.0)")
#     width = PositiveFloat(184.0, doc="thickness of lumber in metric (mm) units (default: 184.0)")
#
#
# @register("1-1/2x10")
# class Lumber1__1_2x10(Lumber):
#     """a 1-1/2"x10" (32x235mm) piece of Lumber"""
#     height = PositiveFloat(32.0, doc="height of lumber in metric (mm) units (default: 32.0)")
#     width = PositiveFloat(235.0, doc="thickness of lumber in metric (mm) units (default: 235.0)")
#
#
# @register("1-1/2x12")
# class Lumber1__1_2x12(Lumber):
#     """a 1-1/2"x12" (32x286mm) piece of Lumber"""
#     height = PositiveFloat(32.0, doc="height of lumber in metric (mm) units (default: 32.0)")
#     width = PositiveFloat(286.0, doc="thickness of lumber in metric (mm) units (default: 286.0)")
#
#
# @register("2x2")
# class Lumber2x2(Lumber):
#     """a 2"x2" (38x38mm) piece of Lumber"""
#     height = PositiveFloat(38.0, doc="height of lumber in metric (mm) units (default: 38.0)")
#     width = PositiveFloat(38.0, doc="thickness of lumber in metric (mm) units (default: 38.0)")
#
#
# @register("2x4")
# class Lumber2x4(Lumber):
#     """a 2"x4" (38x89mm) piece of Lumber"""
#     height = PositiveFloat(38.0, doc="height of lumber in metric (mm) units (default: 38.0)")
#     width = PositiveFloat(89.0, doc="thickness of lumber in metric (mm) units (default: 89.0)")
#
#
# @register("2x6")
# class Lumber2x6(Lumber):
#     """a 2"x6" (38x140mm) piece of Lumber"""
#     height = PositiveFloat(38.0, doc="height of lumber in metric (mm) units (default: 38.0)")
#     width = PositiveFloat(140.0, doc="thickness of lumber in metric (mm) units (default: 140.0)")
#
#
# @register("2x8")
# class Lumber2x8(Lumber):
#     """a 2"x8" (38x184mm) piece of Lumber"""
#     height = PositiveFloat(38.0, doc="height of lumber in metric (mm) units (default: 38.0)")
#     width = PositiveFloat(184.0, doc="thickness of lumber in metric (mm) units (default: 184.0)")
#
#
# @register("2x10")
# class Lumber2x10(Lumber):
#     """a 2"x10" (38x235mm) piece of Lumber"""
#     height = PositiveFloat(38.0, doc="height of lumber in metric (mm) units (default: 38.0)")
#     width = PositiveFloat(235.0, doc="thickness of lumber in metric (mm) units (default: 235.0)")
#
#
# @register("2x12")
# class Lumber2x12(Lumber):
#     """a 2"x12" (38x286mm) piece of Lumber"""
#     height = PositiveFloat(38.0, doc="height of lumber in metric (mm) units (default: 38.0)")
#     width = PositiveFloat(286.0, doc="thickness of lumber in metric (mm) units (default: 286.0)")
#
#
# @register("3x6")
# class Lumber3x6(Lumber):
#     """a 3"x6" (64x140mm) piece of Lumber"""
#     height = PositiveFloat(64.0, doc="height of lumber in metric (mm) units (default: 64.0)")
#     width = PositiveFloat(140.0, doc="thickness of lumber in metric (mm) units (default: 140.0)")
#
#
# @register("4x4")
# class Lumber4x4(Lumber):
#     """a 4"x4" (89x89mm) piece of Lumber"""
#     height = PositiveFloat(89.0, doc="height of lumber in metric (mm) units (default: 89.0)")
#     width = PositiveFloat(89.0, doc="thickness of lumber in metric (mm) units (default: 89.0)")
#
#
# @register("4x6")
# class Lumber4x6(Lumber):
#     """a 4"x6" (89x140mm) piece of Lumber"""
#     height = PositiveFloat(89.0, doc="height of lumber in metric (mm) units (default: 89.0)")
#     width = PositiveFloat(140.0, doc="thickness of lumber in metric (mm) units (default: 140.0)")
